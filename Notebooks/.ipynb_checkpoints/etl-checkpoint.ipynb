# %%
import re
import json
import os
from pathlib import Path

def parse_aptitude_repo():
    # In a notebook, we get the current working directory
    # '..' moves up from the 'Notebooks' folder to the project root
    root_path = Path.cwd().parent 
    dataset = []
    
    # Regex to capture Question, Solution, and Answer
    q_pattern = r"\d+\.\s+\*\*Question\*\*:\s*(.*?)\s*\*\*Solution\*\*:\s*(.*?)\s*\*\*Answer\*\*:\s*(.*?)(?=\n\d+\.|\n#|\Z)"

    print(f"🔍 Searching for README files in: {root_path.resolve()}")

    # Recursively find all README.md files
    for readme_path in root_path.rglob("README.md"):
        
        # Skip the top-level README and any inside the Notebooks folder
        if readme_path.parent == root_path or "Notebooks" in readme_path.parts:
            continue
            
        # Extract Subject and Level from the folder names
        # Example: parts[-3] = Subject, parts[-2] = Level
        try:
            subject = readme_path.parts[-3]
            level = readme_path.parts[-2]
        except IndexError:
            subject, level = "General", "Unknown"

        with open(readme_path, 'r', encoding='utf-8') as f:
            content = f.read()

        # Split content by ## Category Headers
        sections = re.split(r"(##\s+.+?\n)", content)
        current_category = "General"

        for i in range(len(sections)):
            part = sections[i].strip()
            if not part: continue
            
            if part.startswith("##"):
                current_category = part.replace("##", "").strip()
            else:
                matches = re.findall(q_pattern, part, re.DOTALL)
                
                for q_text, sol_text, ans_text in matches:
                    # Clean and format the data
                    user_content = (
                        f"Subject: {subject}\n"
                        f"Level: {level}\n"
                        f"Category: {current_category}\n"
                        f"Question: {q_text.strip()}"
                    )
                    
                    # We combine Solution and Answer for the Assistant response
                    assistant_content = f"Solution: {sol_text.strip()} Answer: {ans_text.strip()}"
                    
                    dataset.append({
                        "messages": [
                            {"role": "user", "content": user_content},
                            {"role": "assistant", "content": assistant_content}
                        ]
                    })

    return dataset

# %%
# --- Execution Section ---

# 1. Parse the data
all_questions = parse_aptitude_repo()

# 2. Save the output inside the Notebooks folder
output_filename = "smollm2_aptitude_train.jsonl"
with open(output_filename, "w", encoding="utf-8") as f:
    for entry in all_questions:
        f.write(json.dumps(entry, ensure_ascii=False) + "\n")

print(f"--- Extraction Complete ---")
print(f"✅ Total Questions Parsed: {len(all_questions)}")
print(f"📁 Dataset saved to: {os.getcwd()}/{output_filename}")

# 3. Quick Preview of the first item
if all_questions:
    print("\n--- Sample Entry ---")
    print(json.dumps(all_questions[0], indent=2, ensure_ascii=False))
# Out:
# 🔍 Searching for README files in: D:\Others\ETL\ETL-CSE-Aptitude-Test-Practice-Hub
# --- Extraction Complete ---
# ✅ Total Questions Parsed: 1769
# 📁 Dataset saved to: D:\Others\ETL\ETL-CSE-Aptitude-Test-Practice-Hub\Notebooks/smollm2_aptitude_train.jsonl
#
# --- Sample Entry ---
# {
#   "messages": [
#     {
#       "role": "user",
#       "content": "Subject: 06 Technical Aptitude (Basic Programming and AIML Concepts)\nLevel: 01 Basic\nCategory: Programming Fundamentals (1–20)\nQuestion: What is the output of this C code: `int x = 5; printf(\"%d\", x++);`?"
#     },
#     {
#       "role": "assistant",
#       "content": "Solution: `x++` is post-increment, so `printf` uses the current value of `x` (5), then increments `x` to 6. Answer: 5"
#     }
#   ]
# }

# %%
## 🚀 Push to Hugging Face
from datasets import load_dataset
from huggingface_hub import login

# 1. Login (it will ask for your token)
login()

# 2. Load the JSONL file
dataset = load_dataset("json", data_files="./train_data_final.jsonl")

# 3. Push to Hub
# Change 'your-username' to your actual HF username
dataset.push_to_hub("Prathamesh25/aptitude-qa-dataset")

print("Done! Your dataset is now live.")
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 9
#       5 # 1. Login (it will ask for your token)
#       6 login()
#       7
#       8 # 2. Load the JSONL file
# ----> 9 dataset = load_dataset("json", data_files="./train_data_final.jsonl")
#      10
#      11 # 3. Push to Hub
#      12 # Change 'your-username' to your actual HF username
#
# File d:\Others\ETL\ETL-CSE-Aptitude-Test-Practice-Hub\.venv\Lib\site-packages\datasets\load.py:1688, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1683 verification_mode = VerificationMode(
#    1684     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1685 )
#    1687 # Create a dataset builder
# -> 1688 builder_instance = load_dataset_builder(
#    1689     path=path,
#    1690     name=name,
#    1691     data_dir=data_dir,
#    1692     data_files=data_files,
#    1693     cache_dir=cache_dir,
#    1694     features=features,
#    1695     download_config=download_config,
#    1696     download_mode=download_mode,
#    1697     revision=revision,
#    1698     token=token,
#    1699     storage_options=storage_options,
#    1700     **config_kwargs,
#    1701 )
#    1703 # Return iterable dataset in case of streaming
#    1704 if streaming:
#
# File d:\Others\ETL\ETL-CSE-Aptitude-Test-Practice-Hub\.venv\Lib\site-packages\datasets\load.py:1315, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1313 if features is not None:
#    1314     features = _fix_for_backward_compatible_features(features)
# -> 1315 dataset_module = dataset_module_factory(
#    1316     path,
#    1317     revision=revision,
#    1318     download_config=download_config,
#    1319     download_mode=download_mode,
#    1320     data_dir=data_dir,
#    1321     data_files=data_files,
#    1322     cache_dir=cache_dir,
#    1323 )
#    1324 # Get dataset builder class
#    1325 builder_kwargs = dataset_module.builder_kwargs
#
# File d:\Others\ETL\ETL-CSE-Aptitude-Test-Practice-Hub\.venv\Lib\site-packages\datasets\load.py:1055, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1047 # Try packaged
#    1048 if path in _PACKAGED_DATASETS_MODULES:
#    1049     return PackagedDatasetModuleFactory(
#    1050         path,
#    1051         data_dir=data_dir,
#    1052         data_files=data_files,
#    1053         download_config=download_config,
#    1054         download_mode=download_mode,
# -> 1055     ).get_module()
#    1056 # Try locally
#    1057 elif path.endswith(filename):
#
# File d:\Others\ETL\ETL-CSE-Aptitude-Test-Practice-Hub\.venv\Lib\site-packages\datasets\load.py:533, in PackagedDatasetModuleFactory.get_module(self)
#     527 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     528 patterns = (
#     529     sanitize_patterns(self.data_files)
#     530     if self.data_files is not None
#     531     else get_data_patterns(base_path, download_config=self.download_config)
#     532 )
# --> 533 data_files = DataFilesDict.from_patterns(
#     534     patterns,
#     535     download_config=self.download_config,
#     536     base_path=base_path,
#     537 )
#     539 module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     541 builder_kwargs = {
#     542     "data_files": data_files,
#     543     "dataset_name": self.name,
#     544 }
#
# File d:\Others\ETL\ETL-CSE-Aptitude-Test-Practice-Hub\.venv\Lib\site-packages\datasets\data_files.py:723, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     718 out = cls()
#     719 for key, patterns_for_key in patterns.items():
#     720     out[key] = (
#     721         patterns_for_key
#     722         if isinstance(patterns_for_key, DataFilesList)
# --> 723         else DataFilesList.from_patterns(
#     724             patterns_for_key,
#     725             base_path=base_path,
#     726             allowed_extensions=allowed_extensions,
#     727             download_config=download_config,
#     728         )
#     729     )
#     730 return out
#
# File d:\Others\ETL\ETL-CSE-Aptitude-Test-Practice-Hub\.venv\Lib\site-packages\datasets\data_files.py:616, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     613 for pattern in patterns:
#     614     try:
#     615         data_files.extend(
# --> 616             resolve_pattern(
#     617                 pattern,
#     618                 base_path=base_path,
#     619                 allowed_extensions=allowed_extensions,
#     620                 download_config=download_config,
#     621             )
#     622         )
#     623     except FileNotFoundError:
#     624         if not has_magic(pattern):
#
# File d:\Others\ETL\ETL-CSE-Aptitude-Test-Practice-Hub\.venv\Lib\site-packages\datasets\data_files.py:403, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     401     if allowed_extensions is not None:
#     402         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 403     raise FileNotFoundError(error_msg)
#     404 return out
#
# FileNotFoundError: Unable to find 'D:/Others/ETL/ETL-CSE-Aptitude-Test-Practice-Hub/Notebooks\./train_data_final.jsonl'

# %%
! pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipywidgets) (9.13.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: colorama>=0.4.4 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: psutil>=7 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in d:\others\etl\etl-cse-aptitude-test-practice-hub\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    ---------------------- ----------------- 524.3/914.9 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 914.9/914.9 kB 1.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 1.7 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.2 MB 1.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 2.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 1.7 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    ---------------------------------------- 3/3 [ipywidgets]
#
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
